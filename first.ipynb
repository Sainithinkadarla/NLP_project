# %%
import string
test  =  "I love Python !"
lower = test.lower()
lower
# Out:
# 'i love python !'

# %%
translated = lower.translate(str.maketrans(" "," ",string.punctuation))

# %%
translated
# Out:
# 'i love python '

# %%
tokenized = translated.split()

# %%
tokenized
# Out:
# ['i', 'love', 'python']
